# %%
import numpy as np
import matplotlib.pyplot as plt
import ecco_v4_py as ecco
import sys
sys.path.append('/home3/sreich/MITgcm_c68w/MITgcm/utils/python/MITgcmutils')

from MITgcmutils import rdmds

# %%
run_dir='/nobackup/sreich/llc270_c68w_runs/run_ad_pk0000841536_ke/ctrl_variables/'
adxx_theta = rdmds(run_dir+'adxx_theta.0000000000')

# %%
np.unique(adxx_theta) #nz, ny, nx
# Out:
# array([0.])

# %%
xx_theta = rdmds(run_dir+'xx_theta.0000000000')
np.unique(xx_theta)
# Out:
# array([0.])

# %%
xx_theta_effective = rdmds(run_dir+'xx_theta.effective.0000000000')
np.unique(xx_theta_effective)
# Out:
# array([-2.        , -1.98031545, -1.97952271, ..., 33.57823944,
#        33.58902359, 33.62088394])

# %%
plt.pcolormesh(xx_theta[0,:,:])
plt.colorbar()
